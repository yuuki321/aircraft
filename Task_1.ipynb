# %% [markdown]
# <a href="https://colab.research.google.com/github/yuuki321/aircraft/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

import requests
from datetime import datetime, timedelta
import json  # Import the json module

# Function to fetch and store flight data for a specific date
def fetch_flight_data(date):
    url = f"https://www.hongkongairport.com/flightinfo-rest/rest/flights?span=1&date={date}&lang=en&cargo=false&arrival=false"
    response = requests.get(url)

    if response.status_code == 200:
        flights_data = response.json()
        flight_list = []

        for flight_info in flights_data[0]['list']:
            for flight in flight_info['flight']:
                flight_data = {
                    'flightNo': flight['no'],
                    'airline': flight['airline'],
                    'date': date,
                    'time': flight_info['time'],
                    'status': flight_info['status'],
                    'destination': flight_info['destination'][0],
                    'terminal': flight_info['terminal'],
                    'aisle': flight_info['aisle'],
                    'gate': flight_info['gate']
                }
                flight_list.append(flight_data)

        return flight_list
    else:
        print(f"Failed to fetch data for {date}. Status code: {response.status_code}")
        return []

# Loop through each date in August 2024
start_date = datetime(2024, 8, 1)
end_date = datetime(2024, 8, 31)
current_date = start_date

all_flights = []

while current_date <= end_date:
    date_str = current_date.strftime('%Y-%m-%d')
    flights = fetch_flight_data(date_str)
    all_flights.extend(flights)
    current_date += timedelta(days=1)

# Write all_flights into json file here
with open('all_flights_august_2024.json', 'w') as json_file:
    json.dump(all_flights, json_file, indent=4)  # Write JSON data with indentation for readability

# Now all_flights contains the structured data
for flight in all_flights:
    print(flight)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# {'flightNo': 'HX 232', 'airline': 'CRK', 'date': '2024-08-25', 'time': '19:05', 'status': 'Dep 19:17', 'destination': 'PVG', 'terminal': 'T1', 'aisle': 'K', 'gate': '204'}
# {'flightNo': 'HU 8509', 'airline': 'CHH', 'date': '2024-08-25', 'time': '19:05', 'status': 'Dep 19:17', 'destination': 'PVG', 'terminal': 'T1', 'aisle': 'K', 'gate': '204'}
# {'flightNo': 'CX 797', 'airline': 'CPA', 'date': '2024-08-25', 'time': '19:05', 'status': 'Dep 19:14', 'destination': 'CGK', 'terminal': 'T1', 'aisle': 'C', 'gate': '35'}
# {'flightNo': 'BA 4575', 'airline': 'BAW', 'date': '2024-08-25', 'time': '19:05', 'status': 'Dep 19:14', 'destination': 'CGK', 'terminal': 'T1', 'aisle': 'C', 'gate': '35'}
# {'flightNo': 'QR 5809', 'airline': 'QTR', 'date': '2024-08-25', 'time': '19:05', 'status': 'Dep 19:14', 'destination': 'CGK', 'terminal': 'T1', 'aisle': 'C', 'gate': '35'}
# ...
